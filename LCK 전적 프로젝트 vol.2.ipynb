# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import re
import requests

# %%
path = r'C:\\Users\\2106-017\\Documents\\practice\\01_data\\no\\chrome\\chromedriver.exe'

# %%
url = open(r'C:\\Users\\2106-017\\Documents\\lck_project\\LoL e-sports 기록실 - 선수 개인 기록 - 리그오브레전드 인벤.html', 'rt', encoding = 'utf-8')
soup = BeautifulSoup(url, 'html.parser')

# %%
lil = soup.find_all('div', class_='listTable')[0].find('tbody').find_all('tr')
match_play = len(soup.find_all('div', class_='listTable')[0].find('tbody').find_all('tr'))

type_1 = lil[2].find_all('td')[0].text
type_2 = lil[2].find_all('td')[1].text
type_3 = lil[2].find_all('td')[2].text
type_4 = lil[2].find_all('td')[3].text
type_5 = lil[2].find_all('td')[5].text
type_6 = lil[2].find_all('td')[6].text
type_7 = lil[2].find_all('td')[7].text
type_8 = lil[2].find_all('td')[8].text
type_9 = lil[2].find_all('td')[9].text
type_10 = lil[2].find_all('td')[10].text
type_11 = re.sub(r"LOL.CommonLayer.showText\(|\);", "", lil[2].find_all('td')[4].find_all('img')[0].get('onmouseover'))
type_12 = re.sub(r"LOL.CommonLayer.showText\(|\);", "",lil[2].find_all('td')[4].find_all('img')[1].get('onmouseover'))
print(type_1)
print(type_2),
print(type_3),
print(type_4),
print(type_5),
print(type_6),
print(type_7),
print(type_8),
print(type_9),
print(type_10)
print(type_11)
print(type_12)
# Out:
# 22.02.24
# 2022 LCK 스프링
# DK ShowMaker
# 아칼리
# 패
# 2
# 5
# 5
# 1.4
# 58%
# '순간이동'
# '점멸'

# %%
t = type_12.get("onmouseover")
t
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18244/4024590771.py in <module>
# ----> 1 t = type_12.get("onmouseover")
#       2 t
#
# AttributeError: 'str' object has no attribute 'get'

# %%
re.sub(r"""LOL.CommonLayer.showText\(|\);""", "",t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18244/1767752337.py in <module>
# ----> 1 re.sub(r"""LOL.CommonLayer.showText\(|\);""", "",t)
#
# NameError: name 't' is not defined

# %%
len(soup.find_all('div', class_='listTable')[0].find('tbody').find_all('tr'))
# Out:
# 1250

# %%
match_record = []

for i in range (match_play):
    lil = soup.find_all('div', class_='listTable')[0].find('tbody').find_all('tr')

    type_1 = lil[i].find_all('td')[0].text#경기 날짜
    type_2 = lil[i].find_all('td')[1].text#시즌
    type_3 = lil[i].find_all('td')[2].text#선수
    type_4 = lil[i].find_all('td')[3].text#챔프
    type_5 = lil[i].find_all('td')[5].text#결과
    type_6 = lil[i].find_all('td')[6].text#킬
    type_7 = lil[i].find_all('td')[7].text#데스
    type_8 = lil[i].find_all('td')[8].text#어시스트
    type_9 = lil[i].find_all('td')[9].text#kda
    type_10 = lil[i].find_all('td')[10].text# 킬관여율
    type_11 = re.sub(r"LOL.CommonLayer.showText\(|\);", "", lil[i].find_all('td')[4].find_all('img')[0].get('onmouseover'))#d spell
    type_12 = re.sub(r"LOL.CommonLayer.showText\(|\);", "",lil[i].find_all('td')[4].find_all('img')[1].get('onmouseover'))#f spell
    
    
    match_record.append([type_1,type_2,type_3,type_4,type_11,type_12,type_5,type_6,type_7,type_8,type_9,type_10])
    


match_record
# Out:
# [['22.02.24',
#   '2022 LCK 스프링',
#   'DK Burdol',
#   '그웬',
#   "'순간이동'",
#   "'유체화'",
#   '패',
#   '4',
#   '2',
#   '1',
#   '2.5',
#   '42%'],
#  ['22.02.24',
#   '2022 LCK 스프링',
#   'DK Canyon',
#   '리 신',
#   "'강타'",
#   "'점멸'",
#   '패',
#   '0',
#   '3',
#   '8',
#   '2.7',
#   '67%'],
#  ['22.02.24',
#   '2022 LCK 스프링',
#   'DK ShowMaker',
#   '아칼리',
#   "'순간이동'",
#   "'점멸'",
#   '패',
#   '2',
#   '5',
#   '5',
#   '1.4',
#   '58%'],
#  ['22.02.24',
#   '2022 LCK 스프링',
#   'DK deokdam',
#   '이즈리얼',
#   "'점멸'",
#   "'탈진'",
#   '패',
#   '5',
#   '1',
#   '3',
#   '8',
#   '67%'],
#  ['22.02.24',
#   '2022 LCK 스프링',
#   'DK Kellin',
#   '카르마',
#   "'점화'",
#   "'점멸'",
#   '패',
#   '1',
#   '1',
#   '10',
#   '11',
#   '92%'],
#  ['22.02.24',
#   '2022 LCK 스프링',
#   'T1 Zeus',
#   '케넨',
#   "'순간이동'",
#   "'점멸'",
#   '승',
#   '3',
#   '1',
#   '6',
#   '9',
#   '75%'],
#  ['22.02.24',
#   '2022 LCK 스프링',
#   'T1 Oner',
#   '신 짜오',
#   "'강타'",
#   "'점멸'",
#   '승',
#   '4',
#   '3',
# ...

# %%
url_1 = open(r'C:\\Users\\2106-017\\Documents\\lck_project\\LoL e-sports 기록실 - 경기 세부 결과 - 리그오브레전드 인벤pg1.html', 'rt', encoding = 'utf-8')
soup_1 = BeautifulSoup(url_1, 'html.parser')

# %%
len(soup_1.find_all('div', class_='listFrame'))
# 25경기
# Out:
# 25

# %%
quq = soup_1.find_all('div', class_='listFrame')[0].find('div', class_='gametime').text.strip()
print(quq)
# Out:
# PLAY TIME
# 					46분 16초

# %%
quq
# Out:
# 'PLAY TIME\n\t\t\t\t\t46분 16초'

# %%
re.sub(r"\n|\t|PLAY TIME","", quq)
# Out:
# '46분 16초'

# %%
pop=re.sub('LOL.CommonLayer.showText\(|\);','',soup_1.find_all('div', class_='listFrame')[0].find_all('div', class_='lTeam')[0].find_all('li')[1].find('img').get('onmouseover'))
print(pop)
# Out:
# '신 짜오'

# %%
soup_1.find_all('div', class_='listFrame')[0].find_all('div', class_='lTeam')[0].find_all('li')[10]
# Out:
# <li><span class="tx1">BAN</span></li>

# %%
lil_1 = soup_1.find_all('div', class_='listFrame')

#play info
qplay_date=lil_1[0].find('div', class_='listTop').find('div',class_='date').text
qplay_seasons=lil_1[0].find('div', class_='listTop').find('div',class_='title').text
qplay_set=lil_1[0].find('div', class_='listTop').find('div',class_='stage').text
#team name
qright_team=lil_1[0].find('div', class_='wTeam').find('a').text
qleft_team=lil_1[0].find('div', class_='lTeam').find('a').text
#play time
qplay_time=re.sub(r'\n|\t|PLAY TIME','',lil_1[0].find('div', class_='gametime').text.strip())
#left team
ql_team_kill=lil_1[0].find_all('div', class_='teamscore')[0].find_all('span')[1].text
ql_team_death=lil_1[0].find_all('div', class_='teamscore')[0].find_all('span')[3].text
ql_team_ass=lil_1[0].find_all('div', class_='teamscore')[0].find_all('span')[5].text
ql_team_kda=lil_1[0].find_all('div', class_='teamscore')[0].find_all('span')[7].text
ql_play_result=lil_1[0].find('div', class_='rightPart').text
#right team
qr_team_kill=lil_1[0].find_all('div', class_='teamscore')[1].find_all('span')[1].text
qr_team_death=lil_1[0].find_all('div', class_='teamscore')[1].find_all('span')[3].text
qr_team_ass=lil_1[0].find_all('div', class_='teamscore')[1].find_all('span')[5].text
qr_team_kda=lil_1[0].find_all('div', class_='teamscore')[1].find_all('span')[7].text
qr_play_result=lil_1[0].find_all('div', class_='leftPart')[1].find('div').text

#left team pick
ql_team_pick_1=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='wTeam')[0].find_all('li')[0].find('img').get('onmouseover'))
ql_team_pick_2=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='wTeam')[0].find_all('li')[1].find('img').get('onmouseover'))
ql_team_pick_3=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='wTeam')[0].find_all('li')[2].find('img').get('onmouseover'))
ql_team_pick_4=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='wTeam')[0].find_all('li')[3].find('img').get('onmouseover'))
ql_team_pick_5=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='wTeam')[0].find_all('li')[4].find('img').get('onmouseover'))
#left team ben
ql_team_ben_1=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='wTeam')[0].find_all('li')[6].find('img').get('onmouseover'))
ql_team_ben_2=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='wTeam')[0].find_all('li')[7].find('img').get('onmouseover'))
ql_team_ben_3=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='wTeam')[0].find_all('li')[8].find('img').get('onmouseover'))
ql_team_ben_4=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='wTeam')[0].find_all('li')[9].find('img').get('onmouseover'))
ql_team_ben_5=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='wTeam')[0].find_all('li')[10].find('img').get('onmouseover'))
#right team pick
qr_team_pick_1=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='lTeam')[0].find_all('li')[0].find('img').get('onmouseover'))
qr_team_pick_2=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='lTeam')[0].find_all('li')[1].find('img').get('onmouseover'))
qr_team_pick_3=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='lTeam')[0].find_all('li')[2].find('img').get('onmouseover'))
qr_team_pick_4=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='lTeam')[0].find_all('li')[3].find('img').get('onmouseover'))
qr_team_pick_5=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='lTeam')[0].find_all('li')[4].find('img').get('onmouseover'))
#right team ben
qr_team_ben_1=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='lTeam')[0].find_all('li')[5].find('img').get('onmouseover'))
qr_team_ben_2=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='lTeam')[0].find_all('li')[6].find('img').get('onmouseover'))
qr_team_ben_3=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='lTeam')[0].find_all('li')[7].find('img').get('onmouseover'))
qr_team_ben_4=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='lTeam')[0].find_all('li')[8].find('img').get('onmouseover'))
qr_team_ben_5=re.sub('LOL.CommonLayer.showText\(|\);','',lil_1[0].find_all('div', class_='lTeam')[0].find_all('li')[9].find('img').get('onmouseover'))


print(qplay_date)
print(qplay_seasons)
print(qplay_set)

print(qright_team)

print(qleft_team)

print(qplay_time)

print(ql_team_kill)
print(ql_team_death)
print(ql_team_ass)
print(ql_team_kda)
print(ql_play_result)

print(qr_team_kill)
print(qr_team_death)
print(qr_team_ass)
print(qr_team_kda)
print(qr_play_result)

print(ql_team_pick_1)
print(ql_team_pick_2)
print(ql_team_pick_3)
print(ql_team_pick_4)
print(ql_team_pick_5)

print(ql_team_ben_1)
print(ql_team_ben_2)
print(ql_team_ben_3)
print(ql_team_ben_4)
print(ql_team_ben_5)

print(qr_team_pick_1)
print(qr_team_pick_2)
print(qr_team_pick_3)
print(qr_team_pick_4)
print(qr_team_pick_5)

print(qr_team_ben_1)
print(qr_team_ben_2)
print(qr_team_ben_3)
print(qr_team_ben_4)
print(qr_team_ben_5)
# Out:
# 2022.02.24
# 2022 LoL 챔피언스 코리아 스프링 정규 시즌
# 26일차 2경기 2세트
# DWG KIA
# T1
# 46분 16초
# 12
# 12
# 27
# 3.3
# L
# 12
# 12
# 32
# 3.7
# W
# '리 신'
# '이즈리얼'
# '카르마'
# '아칼리'
# '그웬'
# '아리'
# '케이틀린'
# '아펠리오스'
# '아지르'
# '그라가스'
# '징크스'
# '신 짜오'
# '탐 켄치'
# '빅토르'
# '케넨'
# '트위스티드 페이트'
# '제리'
# '라이즈'
# '르블랑'
# '제이스'

# %%
match_record_1 = []
for i in range(len(soup_1.find_all('div', class_='listFrame'))):
    tot_info = soup_1.find_all('div', class_='listFrame')
    l_pick_ben=tot_info[i].find_all('div', class_='wTeam')[0].find_all('li')
    r_pick_ben=tot_info[i].find_all('div', class_='lTeam')[0].find_all('li')
    team_score_ex = tot_info[i].find_all('div', class_='teamscore')

    #play info
    play_date=lil_1[i].find('div', class_='listTop').find('div',class_='date').text
    play_seasons=lil_1[i].find('div', class_='listTop').find('div',class_='title').text
    play_set=lil_1[i].find('div', class_='listTop').find('div',class_='stage').text
    #team name
    right_team=lil_1[i].find('div', class_='wTeam').find('a').text
    left_team=lil_1[i].find('div', class_='lTeam').find('a').text
    #play time
    play_time=re.sub(r'\n|\t|PLAY TIME','',lil_1[i].find('div', class_='gametime').text.strip())
    #left team
    l_team_kill=team_score_ex[0].find_all('span')[1].text
    l_team_death=team_score_ex[0].find_all('span')[3].text
    l_team_ass=team_score_ex[0].find_all('span')[5].text
    l_team_kda=team_score_ex[0].find_all('span')[7].text
    l_play_result=lil_1[i].find('div', class_='rightPart').text
    #right team
    r_team_kill=team_score_ex[1].find_all('span')[1].text
    r_team_death=team_score_ex[1].find_all('span')[3].text
    r_team_ass=team_score_ex[1].find_all('span')[5].text
    r_team_kda=team_score_ex[1].find_all('span')[7].text
    r_play_result=lil_1[i].find_all('div', class_='leftPart')[1].find('div').text

    #left team pick
    l_team_pick_1=re.sub('LOL.CommonLayer.showText\(|\);','',l_pick_ben[0].find('img').get('onmouseover'))
    l_team_pick_2=re.sub('LOL.CommonLayer.showText\(|\);','',l_pick_ben[1].find('img').get('onmouseover'))
    l_team_pick_3=re.sub('LOL.CommonLayer.showText\(|\);','',l_pick_ben[2].find('img').get('onmouseover'))
    l_team_pick_4=re.sub('LOL.CommonLayer.showText\(|\);','',l_pick_ben[3].find('img').get('onmouseover'))
    l_team_pick_5=re.sub('LOL.CommonLayer.showText\(|\);','',l_pick_ben[4].find('img').get('onmouseover'))
    #left team ben
    l_team_ben_1=re.sub('LOL.CommonLayer.showText\(|\);','',l_pick_ben[6].find('img').get('onmouseover'))
    l_team_ben_2=re.sub('LOL.CommonLayer.showText\(|\);','',l_pick_ben[7].find('img').get('onmouseover'))
    l_team_ben_3=re.sub('LOL.CommonLayer.showText\(|\);','',l_pick_ben[8].find('img').get('onmouseover'))
    l_team_ben_4=re.sub('LOL.CommonLayer.showText\(|\);','',l_pick_ben[9].find('img').get('onmouseover'))
    l_team_ben_5=re.sub('LOL.CommonLayer.showText\(|\);','',l_pick_ben[10].find('img').get('onmouseover'))
    #right team pick
    r_team_pick_1=re.sub('LOL.CommonLayer.showText\(|\);','',r_pick_ben[0].find('img').get('onmouseover'))
    r_team_pick_2=re.sub('LOL.CommonLayer.showText\(|\);','',r_pick_ben[1].find('img').get('onmouseover'))
    r_team_pick_3=re.sub('LOL.CommonLayer.showText\(|\);','',r_pick_ben[2].find('img').get('onmouseover'))
    r_team_pick_4=re.sub('LOL.CommonLayer.showText\(|\);','',r_pick_ben[3].find('img').get('onmouseover'))
    r_team_pick_5=re.sub('LOL.CommonLayer.showText\(|\);','',r_pick_ben[4].find('img').get('onmouseover'))
    #right team ben
    r_team_ben_1=re.sub('LOL.CommonLayer.showText\(|\);','',r_pick_ben[5].find('img').get('onmouseover'))
    r_team_ben_2=re.sub('LOL.CommonLayer.showText\(|\);','',r_pick_ben[6].find('img').get('onmouseover'))
    r_team_ben_3=re.sub('LOL.CommonLayer.showText\(|\);','',r_pick_ben[7].find('img').get('onmouseover'))
    r_team_ben_4=re.sub('LOL.CommonLayer.showText\(|\);','',r_pick_ben[8].find('img').get('onmouseover'))
    r_team_ben_5=re.sub('LOL.CommonLayer.showText\(|\);','',r_pick_ben[9].find('img').get('onmouseover'))
    
    match_record_1.append([play_date,play_seasons,play_set,right_team,left_team,play_time,l_team_kill,l_team_death,l_team_ass,l_team_kda,l_play_result,r_team_kill,r_team_death,r_team_ass,r_team_kda,r_play_result,l_team_pick_1,l_team_pick_2,l_team_pick_3,l_team_pick_4,l_team_pick_5,l_team_ben_1,l_team_ben_2,l_team_ben_3,l_team_ben_4,l_team_ben_5,r_team_pick_1,r_team_pick_2,r_team_pick_3,r_team_pick_4,r_team_pick_5,r_team_ben_1,r_team_ben_2,r_team_ben_3,r_team_ben_4,r_team_ben_5])
match_record_1
# Out:
# [['2022.02.24',
#   '2022 LoL 챔피언스 코리아 스프링 정규 시즌',
#   '26일차 2경기 2세트',
#   'DWG KIA',
#   'T1',
#   '46분 16초',
#   '12',
#   '12',
#   '27',
#   '3.3',
#   'L',
#   '12',
#   '12',
#   '32',
#   '3.7',
#   'W',
#   "'리 신'",
#   "'이즈리얼'",
#   "'카르마'",
#   "'아칼리'",
#   "'그웬'",
#   "'아리'",
#   "'케이틀린'",
#   "'아펠리오스'",
#   "'아지르'",
#   "'그라가스'",
#   "'징크스'",
#   "'신 짜오'",
#   "'탐 켄치'",
#   "'빅토르'",
#   "'케넨'",
#   "'트위스티드 페이트'",
#   "'제리'",
#   "'라이즈'",
#   "'르블랑'",
#   "'제이스'"],
#  ['2022.02.23',
#   '2022 LoL 챔피언스 코리아 스프링 정규 시즌',
#   '26일차 2경기 1세트',
#   'T1',
#   'DWG KIA',
#   '30분 5초',
#   '22',
#   '11',
#   '49',
#   '6.5',
#   'W',
#   '11',
#   '22',
#   '12',
#   '1',
#   'L',
#   "'케이틀린'",
#   "'신 짜오'",
#   "'럭스'",
#   "'아지르'",
#   "'나르'",
#   "'자르반 4세'",
#   "'카르마'",
#   "'라이즈'",
#   "'헤카림'",
#   "'제이스'",
#   "'징크스'",
#   "'아리'",
#   "'레오나'",
#   "'비에고'",
#   "'그웬'",
#   "'제리'",
#   "'트위스티드 페이트'",
#   "'리 신'",
#   "'르블랑'",
#   "'그라가스'"],
#  ['2022.02.23',
# ...

# %%
def match_record_1_append_df(n):
  match_data = []
  for _ in range(n):
    data.append(match_record_1)
  return pd.DataFrame(match_data, columns=['경기 일자','시즌','세트','팀1','팀2','k','d','a','결과','k_2','d_2','a_2',
                                           '결과_2','픽1','픽2','픽3','픽4','픽5','픽_1','픽_2','픽_3','픽_4','픽_5',
                                          '벤1','벤2','벤3','벤4','벤5','벤_1','벤_2','벤3','벤4','벤5'])

# %%
match_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27792/3646599983.py in <module>
# ----> 1 match_data
#
# NameError: name 'match_data' is not defined
